# %%
import numpy as np
import pandas as pd

import warnings
warnings.filterwarnings("ignore")

# %%
# Create DataFrame from output_json files

df_lt = pd.read_csv('1-Laptops/laptop_output.csv')
df_mon = pd.read_csv('2-Monitors/monitor_output.csv')
df_pr = pd.read_csv('3-Processor/processor_output.csv')
df_mo = pd.read_csv('4-Mouse/mouse_output.csv')
df_ke = pd.read_csv('5-Keyboard/keyboard_output.csv')
df_ds = pd.read_csv('6-DSLR_Cameras/dslr_output.csv')
df_sm = pd.read_csv('7-Smartphones/smartphone_output.csv')
df_he = pd.read_csv('8-Headphones/headphone_output.csv')

# %%
# Combine all products

df = pd.concat([df_lt,df_mon,df_pr,df_mo,df_ke,df_ds,df_sm,df_he], ignore_index=True)
df
# Out:
#         Product                                              title  \
# 0        Laptop  2021 Newest Lenovo Ideapad 3 Laptop, 15.6 Full...
# 1        Laptop  2021 Newest Acer Aspire 3 17.3'' HD+ Laptop, 4...
# 2        Laptop  Acer Aspire 5 A515-46-R14K Slim Laptop | 15.6"...
# 3        Laptop  HP 15 Laptop, 11th Gen Intel Core i5-1135G7 Pr...
# 4        Laptop  HP Pavilion x360 14” Touchscreen Laptop, 11th ...
# ...         ...                                                ...
# 8387  Headphone  Morpheus 360 Tremors HP4500R Wireless On-Ear H...
# 8388  Headphone  Tamshun USB C Wired Earbuds Headphone with Mic...
# 8389  Headphone  Earbuds Wireless Bluetooth Sports Headphones -...
# 8390  Headphone  Headsets Splitter Adapter, DUKABEL 3.5mm Jack ...
# 8391  Headphone  Kids Headphones for Classroom in Bulk, Keewond...
#
#                                                     url  rating  review_count  \
# 0     https://www.amazon.com/gp/slredirect/picassoRe...     4.5           238
# 1     https://www.amazon.com/gp/slredirect/picassoRe...     5.0             1
# 2     https://www.amazon.com/Acer-A515-46-R14K-Quad-...     4.6         34163
# 3     https://www.amazon.com/HP-i5-1135G7-Processor-...     4.6          1050
# 4     https://www.amazon.com/HP-Touchscreen-i5-1135G...     4.5           189
# ...                                                 ...     ...           ...
# 8387  https://www.amazon.com/Morpheus-360-Headphones...     4.3            77
# 8388  https://www.amazon.com/Tamshun-Headphone-Micro...     3.8            32
# 8389  https://www.amazon.com/Earbuds-Wireless-Blueto...     4.5            16
# 8390  https://www.amazon.com/Headsets-Splitter-Separ...     4.3          2098
# 8391  https://www.amazon.com/Headphones-Classroom-Ke...     3.7            33
#
#        price
# 0     529.00
# 1     749.99
# 2     365.00
# 3     565.00
# 4     659.00
# ...      ...
# 8387   14.99
# 8388   24.99
# 8389   35.99
# 8390    8.49
# 8391   17.99
#
# [8392 rows x 6 columns]

# %%
# Checking the data type

df.dtypes
# Out:
# Product          object
# title            object
# url              object
# rating          float64
# review_count      int64
# price           float64
# dtype: object

# %%
# Checking empty rows

df.isnull().sum()
# Out:
# Product         0
# title           0
# url             0
# rating          0
# review_count    0
# price           0
# dtype: int64

# %%
# Counting values based on 'title' column

df.groupby(['title'])['rating'].count().sort_values(ascending = False).head(10)
# Out:
# title
# Acer Predator Helios 300 PH315-54-760S Gaming Laptop | Intel i7-11800H | NVIDIA GeForce RTX 3060 Laptop GPU | 15.6" Full HD 144Hz 3ms IPS Display | 16GB DDR4 | 512GB SSD | Killer WiFi 6 | RGB Keyboard    3
# HP Envy 13 Laptop, Intel Core i7-1165G7, 8 GB DDR4 RAM, 256 GB SSD Storage, 13.3-inch FHD Touchscreen Display, Windows 10 Home with Fingerprint Reader, Camera Kill Switch (13-ba1010nr, 2020 Model)        2
# 2021 Flagship Dell Inspiron 15 5000 Laptop Computer 15.6" Full HD Display 11th Gen Intel Quad-Core i7-1165G7 32GB DDR4 1TB SSD MaxxAudio Backlit Webcam HDMI WiFi USB-C Win 10                              2
# New Lenovo 3 Chromebook 11.6" HD (1366 X 768) Laptop PC, Intel Celeron N4020 Dual-Core Processor, 4GB RAM, 32GB eMMC, Webcam, WiFi, Bluetooth, Chrome OS, Onyx Black (Google Classroom Ready)               2
# Lenovo ThinkPad T470s 14" FHD Laptop - Intel Core i7-7600U, 16GB RAM, 256GB SSD, Webcam, Windows 10 Pro (Renewed)                                                                                           2
# Acer Aspire 5 A515-46-R14K Slim Laptop | 15.6" Full HD IPS | AMD Ryzen 3 3350U Quad-Core Mobile Processor | 4GB DDR4 | 128GB NVMe SSD | WiFi 6 | Backlit KB | Amazon Alexa | Windows 10 Home (S mode)       2
# Acer Aspire 5 A515-55-35SE, 15.6" Full HD Display, 10th Gen Intel Core i3-1005G1 Processor, 4GB DDR4, 128GB NVMe SSD, Intel WiFi 6 AX201, Backlit KB, Fingerprint Reader, Windows 10 Home (S Mode)          2
# BOSE QuietComfort 35 (Series II) Wireless Headphones, Noise Cancelling - Black (Renewed)                                                                                                                    2
# Acer Aspire 5 A515-56-36UT Slim Laptop | 15.6" Full HD Display | 11th Gen Intel Core i3-1115G4 Processor | 4GB DDR4 | 128GB NVMe SSD | WiFi 6 | Amazon Alexa | Windows 10 Home (S Mode)                     2
# 2021 Dell Inspiron 15 3000 15.6" HD Laptop Computer, Intel Celeron Processor 4205U, 4GB RAM, 128GB PCIe SSD, Intel UHD Graphics 610, Waves MaxxAudio, HD Webcam, Windows 10, Black                          2
# Name: rating, dtype: int64

# %%
# Checking value w.r.t 'Product'

df[df['title']== 'Acer Aspire 5 A517-52-713G, 17.3" Full HD IPS Display, 11th Gen Intel Core i7-1165G7, Intel Iris Xe Graphics, 16GB DDR4, 512GB NVMe SSD, WiFi 6, Fingerprint Reader, Backlit Keyboard']
# Out:
#         Product                                              title  \
# 401      Laptop  Acer Aspire 5 A517-52-713G, 17.3" Full HD IPS ...
# 2918  Processor  Acer Aspire 5 A517-52-713G, 17.3" Full HD IPS ...
#
#                                                     url  rating  review_count  \
# 401   https://www.amazon.com/Acer-A517-52-713G-i7-11...     4.7            40
# 2918  https://www.amazon.com/Acer-A517-52-713G-i7-11...     4.7            40
#
#       price
# 401   942.0
# 2918  942.0

# %%
df = df.drop_duplicates(subset=['title'])
df
# Out:
#         Product                                              title  \
# 0        Laptop  2021 Newest Lenovo Ideapad 3 Laptop, 15.6 Full...
# 1        Laptop  2021 Newest Acer Aspire 3 17.3'' HD+ Laptop, 4...
# 2        Laptop  Acer Aspire 5 A515-46-R14K Slim Laptop | 15.6"...
# 3        Laptop  HP 15 Laptop, 11th Gen Intel Core i5-1135G7 Pr...
# 4        Laptop  HP Pavilion x360 14” Touchscreen Laptop, 11th ...
# ...         ...                                                ...
# 8387  Headphone  Morpheus 360 Tremors HP4500R Wireless On-Ear H...
# 8388  Headphone  Tamshun USB C Wired Earbuds Headphone with Mic...
# 8389  Headphone  Earbuds Wireless Bluetooth Sports Headphones -...
# 8390  Headphone  Headsets Splitter Adapter, DUKABEL 3.5mm Jack ...
# 8391  Headphone  Kids Headphones for Classroom in Bulk, Keewond...
#
#                                                     url  rating  review_count  \
# 0     https://www.amazon.com/gp/slredirect/picassoRe...     4.5           238
# 1     https://www.amazon.com/gp/slredirect/picassoRe...     5.0             1
# 2     https://www.amazon.com/Acer-A515-46-R14K-Quad-...     4.6         34163
# 3     https://www.amazon.com/HP-i5-1135G7-Processor-...     4.6          1050
# 4     https://www.amazon.com/HP-Touchscreen-i5-1135G...     4.5           189
# ...                                                 ...     ...           ...
# 8387  https://www.amazon.com/Morpheus-360-Headphones...     4.3            77
# 8388  https://www.amazon.com/Tamshun-Headphone-Micro...     3.8            32
# 8389  https://www.amazon.com/Earbuds-Wireless-Blueto...     4.5            16
# 8390  https://www.amazon.com/Headsets-Splitter-Separ...     4.3          2098
# 8391  https://www.amazon.com/Headphones-Classroom-Ke...     3.7            33
#
#        price
# 0     529.00
# 1     749.99
# 2     365.00
# 3     565.00
# 4     659.00
# ...      ...
# 8387   14.99
# 8388   24.99
# 8389   35.99
# 8390    8.49
# 8391   17.99
#
# [8140 rows x 6 columns]

# %%
df[df['title']== 'Acer Aspire 5 A517-52-713G, 17.3" Full HD IPS Display, 11th Gen Intel Core i7-1165G7, Intel Iris Xe Graphics, 16GB DDR4, 512GB NVMe SSD, WiFi 6, Fingerprint Reader, Backlit Keyboard']
# Out:
#     Product                                              title  \
# 401  Laptop  Acer Aspire 5 A517-52-713G, 17.3" Full HD IPS ...
#
#                                                    url  rating  review_count  \
# 401  https://www.amazon.com/Acer-A517-52-713G-i7-11...     4.7            40
#
#      price
# 401  942.0

# %%
# Counting items for all products

df.groupby(['Product'])['rating'].count().sort_values(ascending = False)
# Out:
# Product
# Headphone     1092
# Monitor       1077
# DSLR          1071
# Keyboard      1063
# Mouse         1038
# Laptop        1004
# Smartphone     988
# Processor      807
# Name: rating, dtype: int64
