# %%
import numpy as np
import pandas as pd

import warnings
warnings.filterwarnings("ignore")

# %%
# Create DataFrame from output_json file for processor

df = pd.read_json('search_processor_output.jsonl')
df
# Out:
#                                                   title  \
# 0     AMD Ryzen 5 3600 6-Core, 12-Thread Unlocked De...
# 1     Intel Core i7-10700KF Desktop Processor 8 Core...
# 2     Intel Core i5-9400F Desktop Processor 6 Cores ...
# 3     Intel Core i3-10100 Desktop Processor 4 Cores ...
# 4     Intel Core i5-10600K Desktop Processor 6 Cores...
# ...                                                 ...
# 1869  MSI Z490-A PRO ProSeries ATX Motherboard (10th...
# 1870  HP 14-inch Chromebook HD Touchscreen Laptop PC...
# 1871  NETGEAR Nighthawk 12-Stream AX12 Wifi 6 Router...
# 1872  Tablet 10 Inch, Android 10.0 Tablets 2021 with...
# 1873  Dell Latitude 3340 13.3" Laptop, Intel Core i3...
#
#                                                     url              rating  \
# 0     https://www.amazon.com/gp/slredirect/picassoRe...  4.4 out of 5 stars
# 1     https://www.amazon.com/Intel-i7-10700KF-Proces...  4.8 out of 5 stars
# 2     https://www.amazon.com/Intel-i5-9400F-Desktop-...  4.8 out of 5 stars
# 3     https://www.amazon.com/Intel-i3-10100-Desktop-...  4.8 out of 5 stars
# 4     https://www.amazon.com/Intel-i5-10600K-Desktop...  4.8 out of 5 stars
# ...                                                 ...                 ...
# 1869  https://www.amazon.com/MSI-PRO-ProSeries-Mothe...  4.3 out of 5 stars
# 1870  https://www.amazon.com/HP-14-inch-Chromebook-T...  4.5 out of 5 stars
# 1871  https://www.amazon.com/NETGEAR-Nighthawk-12-St...  4.2 out of 5 stars
# 1872  https://www.amazon.com/1280x800-Touchscreen-Mi...  4.3 out of 5 stars
# 1873  https://www.amazon.com/Dell-Latitude-3340-Lapt...  4.1 out of 5 stars
#
#      review_count    price
# 0              19  $248.99
# 1             461  $386.97
# 2           5,138  $169.99
# 3           1,535  $188.99
# 4           1,279     None
# ...           ...      ...
# 1869           35  $169.95
# 1870        1,767     None
# 1871          871  $489.97
# 1872           90     None
# 1873          226  $219.99
#
# [1874 rows x 5 columns]

# %% [markdown]
# ## Performing following operations on the DataFrame
# - Checking data type for the columns
# - Price column: remove '$' and ',', also change the type to float
# - Review_count cloumn: remove ',', also change the type to float
# - Rating column: Extract ONLY product rating form the column
#
# - Check null values for the columns. Remove rows without price, rating and review_count
# - Remove duplicate rows
#
# - Add Product column and write 'processor' in it

# %%
# Checking the data type

df.dtypes
# Out:
# title           object
# url             object
# rating          object
# review_count    object
# price           object
# dtype: object

# %%
df.isnull().sum()
# Out:
# title             0
# url               0
# rating          282
# review_count    282
# price           334
# dtype: int64

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# title           0
# url             0
# rating          0
# review_count    0
# price           0
# dtype: int64

# %%
df.shape
# Out:
# (1307, 5)

# %%
# Price column: remove '$' and ',', also change the type to float

df['price'] = df['price'].str.replace(',', '')
df['price'] = df['price'].str.replace('$', '')
df['price'] = df['price'].astype(float)

# %%
# Review_count cloumn: remove ',', also change the type to float

df['review_count'] = df['review_count'].str.replace(',', '')
df['review_count'] = df['review_count'].astype(float)
df['review_count'] = df['review_count'].astype(int)

# %%
# Rating column: Extract ONLY product rating form the column

df.rating = df.rating.astype('category')
df['rating'] = df['rating'].str.extract("(\d*\.?\d+)", expand=True)

# %%
df.dtypes
# Out:
# title           object
# url             object
# rating          object
# review_count     int64
# price           object
# dtype: object

# %%
df
# Out:
#                                                   title  \
# 0     Intel Core i7-9700K Desktop Processor 8 Cores ...
# 2     AMD Ryzen 5 2600 Processor with Wraith Stealth...
# 3     Intel Core i9-9900K Desktop Processor 8 Cores ...
# 5     Intel Core i9-10850K Desktop Processor 10 Core...
# 6     AMD Ryzen 5 1600 65W AM4 Processor with Wraith...
# ...                                                 ...
# 3052  AMD Ryzen 5 3600 6-Core, 12-Thread Unlocked De...
# 3055  OWC 32.0GB (4X 8GB) DDR3 ECC-R PC10600 1333MHz...
# 3056  Dell Latitude E7450 14in FHD Business Laptop C...
# 3058  ASUS CHROMEBOX3-N3299U Mini PC with Intel Core...
# 3059  Arctic Silver 3.5g High-Density Polysynthetic ...
#
#                                                     url rating  review_count  \
# 0     https://www.amazon.com/Intel-i7-9700K-Desktop-...    4.8          8634
# 2     https://www.amazon.com/AMD-Processor-Wraith-St...    4.8         21436
# 3     https://www.amazon.com/Intel-i9-9900K-Processo...    4.8          1312
# 5     https://www.amazon.com/Intel-i9-10850K-Desktop...    4.9           975
# 6     https://www.amazon.com/AMD-Processor-Wraith-St...    4.8          6637
# ...                                                 ...    ...           ...
# 3052  https://www.amazon.com/gp/slredirect/picassoRe...    4.4            19
# 3055  https://www.amazon.com/OWC-32-0GB-ECC-R-PC1060...    4.7            38
# 3056  https://www.amazon.com/Dell-Latitude-E7450-Bus...    4.1            32
# 3058  https://www.amazon.com/Asus-Core-i3-8130U-DDR4...    4.5            85
# 3059  https://www.amazon.com/High-Density-Polysynthe...    4.8          1031
#
#        price
# 0     255.00
# 2     193.00
# 3     329.99
# 5     408.00
# 6     152.99
# ...      ...
# 3052  248.99
# 3055  109.99
# 3056  320.00
# 3058  393.00
# 3059    6.80
#
# [2133 rows x 5 columns]

# %%
df.groupby(['title'])['rating'].count().sort_values(ascending = False)
# Out:
# title
# AMD Ryzen 5 3600 6-Core, 12-Thread Unlocked Desktop Processor(Tray) with Wraith Stealth Cooler                                                                                                              167
# ASIAHORSE WD-001 120mm 5V ARGB Motherboard 12 Addressable LED 9 Blades Hydraulic Bearing White Case/Radiator Fan (5 Pack-White)                                                                              81
# Noctua NT-H1 3.5g, Pro-Grade Thermal Compound Paste (3.5g)                                                                                                                                                   81
# Gigabyte B550 AORUS ELITE AX V2 (AMD Ryzen 5000/B550/ATX/True 12+2 Phases Digital VRM/PCIe4.0/DDR4/USB3.2 Gen 1/Realtek ALC1200/Intel WiFi 6/2xM.2 Thermal Guard/2.5 GbE LAN/HDMI/DP/Gaming Motherboard)     55
# Mini PC Windows 10, Beelink Mini Computers Intel Broadwell Processor I3-5005U, Desktop Pc 8GB DDR3 256GB SSD, Mini Desktop Computers with HD Graphics Card 5500 4K HD Dual HDMI Use for Home, Business       36
#                                                                                                                                                                                                            ...
# Blackview Tab8 Tablet, 10.1 inch Android 10 Tablets with 64 GB Octa Core Processor, 1920x1200 IPS FHD Display, 13MP+5MP Dual Camera, GPS, FM, 5G WiFi, 3G Phone Grey                                          1
# Blackview Tab 8 Tablet, Android 10 Tablets,4GB RAM+64GM ROM.10.1" FHD Screen 6580 mAh Battery .Octa-Core Processor.WiFi. Bluetooth,GPS(Gold)                                                                  1
# BiTECOOL Laptop 2021 New Windows 10 Pro, 15.6 inches Full HD IPS Display, Intel Celeron Quad Core, 8GB RAM and 256GB SSD, Expandable up to 1TB, Full Size Keyboard, Slim (J4115)                              1
# BenQ GW2780T 27” 1080p IPS Business Monitor | Full HD | Ultra Slim Bezel, Grey                                                                                                                                1
# 【Win10/Office 2010 】 Only 0.8KG 10.1 inch Ultra-Thin Laptop AtomX5 Z8350 Quad Core Processor 2G RAM/32GB EMMC High-spec Performance Notebook (2G+HDD Capacity 64G (Including 32G Micro SD Card), Black)       1
# Name: rating, Length: 1426, dtype: int64

# %%
df = df.drop_duplicates(subset=['title'])
df
# Out:
#                                                   title  \
# 0     Intel Core i7-9700K Desktop Processor 8 Cores ...
# 2     AMD Ryzen 5 2600 Processor with Wraith Stealth...
# 3     Intel Core i9-9900K Desktop Processor 8 Cores ...
# 5     Intel Core i9-10850K Desktop Processor 10 Core...
# 6     AMD Ryzen 5 1600 65W AM4 Processor with Wraith...
# ...                                                 ...
# 3050  Microsoft Surface Pro (5th Gen) (Intel Core i5...
# 3055  OWC 32.0GB (4X 8GB) DDR3 ECC-R PC10600 1333MHz...
# 3056  Dell Latitude E7450 14in FHD Business Laptop C...
# 3058  ASUS CHROMEBOX3-N3299U Mini PC with Intel Core...
# 3059  Arctic Silver 3.5g High-Density Polysynthetic ...
#
#                                                     url rating  review_count  \
# 0     https://www.amazon.com/Intel-i7-9700K-Desktop-...    4.8          8634
# 2     https://www.amazon.com/AMD-Processor-Wraith-St...    4.8         21436
# 3     https://www.amazon.com/Intel-i9-9900K-Processo...    4.8          1312
# 5     https://www.amazon.com/Intel-i9-10850K-Desktop...    4.9           975
# 6     https://www.amazon.com/AMD-Processor-Wraith-St...    4.8          6637
# ...                                                 ...    ...           ...
# 3050  https://www.amazon.com/Microsoft-Surface-Intel...    4.4          1192
# 3055  https://www.amazon.com/OWC-32-0GB-ECC-R-PC1060...    4.7            38
# 3056  https://www.amazon.com/Dell-Latitude-E7450-Bus...    4.1            32
# 3058  https://www.amazon.com/Asus-Core-i3-8130U-DDR4...    4.5            85
# 3059  https://www.amazon.com/High-Density-Polysynthe...    4.8          1031
#
#        price
# 0     255.00
# 2     193.00
# 3     329.99
# 5     408.00
# 6     152.99
# ...      ...
# 3050  699.99
# 3055  109.99
# 3056  320.00
# 3058  393.00
# 3059    6.80
#
# [1426 rows x 5 columns]

# %%
# Inserting 'product name' column at the start

df.insert(0, 'Product', 'Processor')

# %%
df
# Out:
#         Product                                              title  \
# 0     Processor  Intel Core i7-9700K Desktop Processor 8 Cores ...
# 2     Processor  AMD Ryzen 5 2600 Processor with Wraith Stealth...
# 3     Processor  Intel Core i9-9900K Desktop Processor 8 Cores ...
# 5     Processor  Intel Core i9-10850K Desktop Processor 10 Core...
# 6     Processor  AMD Ryzen 5 1600 65W AM4 Processor with Wraith...
# ...         ...                                                ...
# 3050  Processor  Microsoft Surface Pro (5th Gen) (Intel Core i5...
# 3055  Processor  OWC 32.0GB (4X 8GB) DDR3 ECC-R PC10600 1333MHz...
# 3056  Processor  Dell Latitude E7450 14in FHD Business Laptop C...
# 3058  Processor  ASUS CHROMEBOX3-N3299U Mini PC with Intel Core...
# 3059  Processor  Arctic Silver 3.5g High-Density Polysynthetic ...
#
#                                                     url rating  review_count  \
# 0     https://www.amazon.com/Intel-i7-9700K-Desktop-...    4.8          8634
# 2     https://www.amazon.com/AMD-Processor-Wraith-St...    4.8         21436
# 3     https://www.amazon.com/Intel-i9-9900K-Processo...    4.8          1312
# 5     https://www.amazon.com/Intel-i9-10850K-Desktop...    4.9           975
# 6     https://www.amazon.com/AMD-Processor-Wraith-St...    4.8          6637
# ...                                                 ...    ...           ...
# 3050  https://www.amazon.com/Microsoft-Surface-Intel...    4.4          1192
# 3055  https://www.amazon.com/OWC-32-0GB-ECC-R-PC1060...    4.7            38
# 3056  https://www.amazon.com/Dell-Latitude-E7450-Bus...    4.1            32
# 3058  https://www.amazon.com/Asus-Core-i3-8130U-DDR4...    4.5            85
# 3059  https://www.amazon.com/High-Density-Polysynthe...    4.8          1031
#
#        price
# 0     255.00
# 2     193.00
# 3     329.99
# 5     408.00
# 6     152.99
# ...      ...
# 3050  699.99
# 3055  109.99
# 3056  320.00
# 3058  393.00
# 3059    6.80
#
# [1426 rows x 6 columns]
