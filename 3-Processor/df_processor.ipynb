# %%
import numpy as np
import pandas as pd

import warnings
warnings.filterwarnings("ignore")

# %%
# Create DataFrame from output_json file for processor

df = pd.read_json('search_output_processor.jsonl')
df
# Out:
#                                                   title  \
# 0     MOVESPEED 256GB 3D NAND Internal PC SSD - SATA...
# 1     19.5V 11.8A 230W AC Charger Compatible Fit for...
# 2     Intel Core i5-8400 Desktop Processor 6 Cores u...
# 3     Intel Core i9-9900 Desktop Processor 8 Cores u...
# 4     AMD Ryzen 7 3700X 8-Core, 16-Thread Unlocked D...
# ...                                                 ...
# 1341  Anthenn 14.1 Inch FHD Thin and Light Laptop No...
# 1342  waveshare Raspberry Pi Pico Microcontroller De...
# 1343  Tablet 10.1 Inch Android 10 32GB 6000mAh Batte...
# 1344  Raspberry Pi Pico Flexible Microcontroller Min...
# 1345  ASUS VivoBook 15 S513 Thin and Light Laptop, 1...
#
#                                                     url              rating  \
# 0     https://www.amazon.com/gp/slredirect/picassoRe...  4.5 out of 5 stars
# 1     https://www.amazon.com/gp/slredirect/picassoRe...                None
# 2     https://www.amazon.com/Intel-i5-8400-Desktop-P...  4.8 out of 5 stars
# 3     https://www.amazon.com/Intel-i9-9900-Desktop-P...  4.5 out of 5 stars
# 4     https://www.amazon.com/AMD-Ryzen-3700X-16-Thre...  4.9 out of 5 stars
# ...                                                 ...                 ...
# 1341  https://www.amazon.com/Anthenn-Notebook-Proces...  3.5 out of 5 stars
# 1342  https://www.amazon.com/waveshare-Pico-Microcon...  5.0 out of 5 stars
# 1343  https://www.amazon.com/Android-6000mAh-Battery...  4.5 out of 5 stars
# 1344  https://www.amazon.com/Raspberry-Microcontroll...  4.8 out of 5 stars
# 1345  https://www.amazon.com/ASUS-VivoBook-Processor...  4.6 out of 5 stars
#
#      review_count    price
# 0               2   $39.99
# 1            None  $105.88
# 2           2,532  $245.99
# 3             223  $344.98
# 4          22,204     None
# ...           ...      ...
# 1341            2  $399.98
# 1342            4   $13.79
# 1343           22  $101.18
# 1344           74   $10.99
# 1345           56  $799.00
#
# [1346 rows x 5 columns]

# %% [markdown]
# ## Performing following operations on the DataFrame
# - Checking data type for the columns
# - Price column: remove '$' and ',', also change the type to float
# - Review_count cloumn: remove ',', also change the type to float
# - Rating column: Extract ONLY product rating form the column
#
# - Check null values for the columns. Remove rows without price, rating and review_count
# - Remove duplicate rows
#
# - Add Product column and write 'processor' in it

# %%
# Checking the data type

df.dtypes
# Out:
# title           object
# url             object
# rating          object
# review_count    object
# price           object
# dtype: object

# %%
# Price column: remove '$' and ',', also change the type to float

df['price'] = df['price'].str.replace(',', '')
df['price'] = df['price'].str.replace('$', '')
df['price'] = df['price'].astype(float)

# %%
# Review_count cloumn: remove ',', also change the type to float

df['review_count'] = df['review_count'].str.replace(',', '')
df['review_count'] = df['review_count'].astype(float)

# %%
# Rating column: Extract ONLY product rating form the column

df.rating = df.rating.astype('category')
df['RATING'] = df['rating'].str.extract("(\d*\.?\d+)", expand=True)

# %%
df.dtypes
# Out:
# Product           object
# title             object
# url               object
# rating          category
# review_count     float64
# price            float64
# RATING            object
# dtype: object

# %%
#df['Product'] = 'Processor'

df.insert(0, 'Product', 'Processor')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-683976eed7c0> in <module>
#       1 #df['Product'] = 'Processor'
#       2
# ----> 3 df.insert(0, 'Product', 'Processor')
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/frame.py in insert(self, loc, column, value, allow_duplicates)
#    3761         self._ensure_valid_index(value)
#    3762         value = self._sanitize_column(column, value, broadcast=False)
# -> 3763         self._mgr.insert(loc, column, value, allow_duplicates=allow_duplicates)
#    3764
#    3765     def assign(self, **kwargs) -> DataFrame:
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/internals/managers.py in insert(self, loc, item, value, allow_duplicates)
#    1189         if not allow_duplicates and item in self.items:
#    1190             # Should this be a different kind of error??
# -> 1191             raise ValueError(f"cannot insert {item}, already exists")
#    1192
#    1193         if not isinstance(loc, int):
#
# ValueError: cannot insert Product, already exists

# %%
df
# Out:
#         Product                                              title  \
# 0     Processor  MOVESPEED 256GB 3D NAND Internal PC SSD - SATA...
# 2     Processor  Intel Core i5-8400 Desktop Processor 6 Cores u...
# 3     Processor  Intel Core i9-9900 Desktop Processor 8 Cores u...
# 7     Processor  AMD Ryzen 5 1600 Processor with Wraith Spire C...
# 8     Processor  Noctua NT-H1 3.5g, Pro-Grade Thermal Compound ...
# ...         ...                                                ...
# 1341  Processor  Anthenn 14.1 Inch FHD Thin and Light Laptop No...
# 1342  Processor  waveshare Raspberry Pi Pico Microcontroller De...
# 1343  Processor  Tablet 10.1 Inch Android 10 32GB 6000mAh Batte...
# 1344  Processor  Raspberry Pi Pico Flexible Microcontroller Min...
# 1345  Processor  ASUS VivoBook 15 S513 Thin and Light Laptop, 1...
#
#                                                     url              rating  \
# 0     https://www.amazon.com/gp/slredirect/picassoRe...  4.5 out of 5 stars
# 2     https://www.amazon.com/Intel-i5-8400-Desktop-P...  4.8 out of 5 stars
# 3     https://www.amazon.com/Intel-i9-9900-Desktop-P...  4.5 out of 5 stars
# 7     https://www.amazon.com/AMD-Processor-Wraith-Co...  4.7 out of 5 stars
# 8     https://www.amazon.com/gp/slredirect/picassoRe...  4.8 out of 5 stars
# ...                                                 ...                 ...
# 1341  https://www.amazon.com/Anthenn-Notebook-Proces...  3.5 out of 5 stars
# 1342  https://www.amazon.com/waveshare-Pico-Microcon...  5.0 out of 5 stars
# 1343  https://www.amazon.com/Android-6000mAh-Battery...  4.5 out of 5 stars
# 1344  https://www.amazon.com/Raspberry-Microcontroll...  4.8 out of 5 stars
# 1345  https://www.amazon.com/ASUS-VivoBook-Processor...  4.6 out of 5 stars
#
#       review_count   price RATING
# 0              2.0   39.99    4.5
# 2           2532.0  245.99    4.8
# 3            223.0  344.98    4.5
# 7           3819.0  191.81    4.7
# 8          15172.0    7.90    4.8
# ...            ...     ...    ...
# 1341           2.0  399.98    3.5
# 1342           4.0   13.79    5.0
# 1343          22.0  101.18    4.5
# 1344          74.0   10.99    4.8
# 1345          56.0  799.00    4.6
#
# [654 rows x 7 columns]

# %%
df.sort_values(by=['title'], ascending=False)
# Out:
#         Product                                              title  \
# 1342  Processor  waveshare Raspberry Pi Pico Microcontroller De...
# 1139  Processor  waveshare Raspberry Pi Pico Microcontroller De...
# 794   Processor  waveshare Micro:bit V2 Go Kit Pocket-Sized Com...
# 670   Processor  upHere 5-Pack 120mm Silent Intelligent Control...
# 961   Processor  seeed studio Raspberry Pi Pico Flexible Microc...
# ...         ...                                                ...
# 1050  Processor  (Renewed) Apple MacBook Air 13.3" 2560 x 1600 ...
# 701   Processor  (Renewed) Acer C720 11.6in Chromebook Intel Ce...
# 857   Processor  (Refurbished) iPad (2018 Model) with Wi-Fi onl...
# 1209  Processor  (Refurbished) Apple iPad with WiFi, 128GB, Spa...
# 288   Processor  (Refurbished) Apple 13in MacBook Air, 1.8GHz I...
#
#                                                     url              rating  \
# 1342  https://www.amazon.com/waveshare-Pico-Microcon...  5.0 out of 5 stars
# 1139  https://www.amazon.com/waveshare-Raspberry-Pic...  4.7 out of 5 stars
# 794   https://www.amazon.com/waveshare-Micro-Pocket-...  4.5 out of 5 stars
# 670   https://www.amazon.com/gp/slredirect/picassoRe...  4.6 out of 5 stars
# 961   https://www.amazon.com/seeed-studio-Raspberry-...  4.7 out of 5 stars
# ...                                                 ...                 ...
# 1050  https://www.amazon.com/Apple-MacBook-MD313LL-1...  5.0 out of 5 stars
# 701   https://www.amazon.com/Acer-Chromebook-Process...  3.9 out of 5 stars
# 857   https://www.amazon.com/Apple-iPad-2018-Space-R...  4.6 out of 5 stars
# 1209  https://www.amazon.com/Apple-128GB-Space-Model...  4.6 out of 5 stars
# 288   https://www.amazon.com/Apple-MacBook-Processor...  4.4 out of 5 stars
#
#       review_count   price RATING
# 1342           4.0   13.79    5.0
# 1139          12.0    9.59    4.7
# 794            2.0   42.29    4.5
# 670          625.0   29.99    4.6
# 961          116.0    9.99    4.7
# ...            ...     ...    ...
# 1050           4.0  769.00    5.0
# 701          764.0   86.99    3.9
# 857         1235.0  268.00    4.6
# 1209        4001.0  269.00    4.6
# 288          775.0  395.00    4.4
#
# [654 rows x 7 columns]

# %%
df.isnull().sum()
# Out:
# Product         0
# title           0
# url             0
# rating          0
# review_count    0
# price           0
# RATING          0
# dtype: int64

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# Product         0
# title           0
# url             0
# rating          0
# review_count    0
# price           0
# RATING          0
# dtype: int64

# %%
df.shape
# Out:
# (933, 7)

# %%
df.groupby(['title'])['rating'].count().sort_values(ascending = False)
# Out:
# title
# AMD Ryzen 5 3600 6-Core, 12-Thread Unlocked Desktop Processor(Tray) with Wraith Stealth Cooler                                                                                          84
# Noctua NT-H1 3.5g, Pro-Grade Thermal Compound Paste (3.5g)                                                                                                                              66
# MOVESPEED 256GB 3D NAND Internal PC SSD - SATA III 6 Gb/s, 2.5"/7mm, Up to 540 MB/s - YSSDJQB-256GSQ                                                                                    19
# JSER Xiwai BCM94360CS2 BCM943224PCIEBT2 Wireless Card to NGFF M.2 Key A/E-Key Adapter                                                                                                   13
# MOVESPEED 512GB 3D NAND Internal PC SSD - SATA III 6 Gb/s, 2.5"/7mm, Up to 540 MB/s - YSSDJQB-512GSQ                                                                                    12
#                                                                                                                                                                                         ..
# BuzzTV XRS4000 with ARQ100 Remote Bundle - Android 9.0 IPTV Set-Top Box - Faster Than Ever Before - 4K Ultra HD - 4GB RAM 32GB Storage - Latest Graphics Processor - Dual Band WIFI      1
# CHUWI CoreBook Pro Windows 10 Home Laptop Computer, 13” FHD 2160×1440P 2K IPS Display, 8G RAM 256GB SSD with Intel Core i3-6157U Processor Notebook (13inch, Gray)                       1
# CHUWI Hi10 Go 10.1'' Touchscreen Windows 10 Home Tablet PC, Intel Celeron Processor N4500, LPDDR4X 6GB RAM/128GB ROM with Type-c, USB 3.0 (Deep Grey)                                    1
# CHUWI UBook 11.6'' Touchscreen Windows 10 Tablet PC, Intel N4120 Quad Core Processor, 1080P Display, 8GB RAM/256GB SSD with Type-c, USB 3.0(Keyboard and Pen not Included)               1
# waveshare Raspberry Pi Pico Microcontroller Development Board with Pre-soldered Header,Based on RP2040 Chip, Flexible Clock Running up to 133 MHz,Dual-core Arm Cortex M0+ Processor     1
# Name: rating, Length: 654, dtype: int64

# %%
df = df.drop_duplicates(subset=['title'])
df
# Out:
#         Product                                              title  \
# 0     Processor  MOVESPEED 256GB 3D NAND Internal PC SSD - SATA...
# 2     Processor  Intel Core i5-8400 Desktop Processor 6 Cores u...
# 3     Processor  Intel Core i9-9900 Desktop Processor 8 Cores u...
# 7     Processor  AMD Ryzen 5 1600 Processor with Wraith Spire C...
# 8     Processor  Noctua NT-H1 3.5g, Pro-Grade Thermal Compound ...
# ...         ...                                                ...
# 1341  Processor  Anthenn 14.1 Inch FHD Thin and Light Laptop No...
# 1342  Processor  waveshare Raspberry Pi Pico Microcontroller De...
# 1343  Processor  Tablet 10.1 Inch Android 10 32GB 6000mAh Batte...
# 1344  Processor  Raspberry Pi Pico Flexible Microcontroller Min...
# 1345  Processor  ASUS VivoBook 15 S513 Thin and Light Laptop, 1...
#
#                                                     url              rating  \
# 0     https://www.amazon.com/gp/slredirect/picassoRe...  4.5 out of 5 stars
# 2     https://www.amazon.com/Intel-i5-8400-Desktop-P...  4.8 out of 5 stars
# 3     https://www.amazon.com/Intel-i9-9900-Desktop-P...  4.5 out of 5 stars
# 7     https://www.amazon.com/AMD-Processor-Wraith-Co...  4.7 out of 5 stars
# 8     https://www.amazon.com/gp/slredirect/picassoRe...  4.8 out of 5 stars
# ...                                                 ...                 ...
# 1341  https://www.amazon.com/Anthenn-Notebook-Proces...  3.5 out of 5 stars
# 1342  https://www.amazon.com/waveshare-Pico-Microcon...  5.0 out of 5 stars
# 1343  https://www.amazon.com/Android-6000mAh-Battery...  4.5 out of 5 stars
# 1344  https://www.amazon.com/Raspberry-Microcontroll...  4.8 out of 5 stars
# 1345  https://www.amazon.com/ASUS-VivoBook-Processor...  4.6 out of 5 stars
#
#       review_count   price RATING
# 0              2.0   39.99    4.5
# 2           2532.0  245.99    4.8
# 3            223.0  344.98    4.5
# 7           3819.0  191.81    4.7
# 8          15172.0    7.90    4.8
# ...            ...     ...    ...
# 1341           2.0  399.98    3.5
# 1342           4.0   13.79    5.0
# 1343          22.0  101.18    4.5
# 1344          74.0   10.99    4.8
# 1345          56.0  799.00    4.6
#
# [654 rows x 7 columns]
