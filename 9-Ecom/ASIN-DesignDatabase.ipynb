# %%
import numpy as np 
import pandas as pd 
import json
from sqlalchemy import create_engine

# %%
#s = pd.read_csv('/Users/sabeehraza/Desktop/DS_CA-Berlin/amazon_scrape/amazon_scrape/Ecom_df.csv')
#s

# %%
summary2 = pd.read_csv('/Users/sabeehraza/Desktop/DS_CA-Berlin/ASIN-sales_clean.csv') 
summary2
# Out:
# /Users/sabeehraza/Library/Python/3.9/lib/python/site-packages/IPython/core/interactiveshell.py:3169: DtypeWarning: Columns (1) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#                                                     title InvoiceNo StockCode  \
# 0       Fujifilm Instax Mini 8 Instant Film Camera (Ra...  78581587     22726
# 1       Lowepro Photo Hatchback 16L Camera Backpack - ...  78581587     22899
# 2       Neewer NW320 Mini TTL Speedlite Flash Automati...  78581586     22061
# 3               Lowepro Fastpack 350 DSLR Camera Backpack  78581586     23275
# 4       Fujifilm Instax Mini 8 Instant Film Camera (Ra...  78581585     22726
# ...                                                   ...       ...       ...
# 554412  Hohem iSteady X, 3-Axis Foldable Lightweight G...  78579472     71050
# 554413  Hohem iSteady X, 3-Axis Foldable Lightweight G...  78577315     71050
# ...

# %%
#s[s['Product']=='DSLR'].sort_values(by='price', ascending=False)

# %%
#s.Product.value_counts()

# %%
summary2.continent.value_counts(ascending=True)
# Out:
# Africa          59
# Americas       382
# Unknown        462
# Oceania       1237
# Asia          1963
# Europe      550314
# Name: continent, dtype: int64

# %%
summary2.product_type.value_counts(ascending=True)
# Out:
# monitor         21974
# processor       71551
# dslr camera     96531
# mouse          101728
# keyboard       128524
# smartphone     134109
# Name: product_type, dtype: int64

# %%
summary2.CustomerID.value_counts(ascending=False)
# Out:
# Null       139315
# 17841.0      8205
# 14911.0      5966
# 14096.0      5377
# 12748.0      4787
#             ...
# 13099.0         1
# 13841.0         1
# 17846.0         1
# 17948.0         1
# 18084.0         1
# Name: CustomerID, Length: 4340, dtype: int64

# %%
#summary2['Country'].value_counts().plot(kind='pie')

# %%
#summary2.isnull()

# %%
#summary2.sort_values(by='invoice_date', ascending= False).value_counts()

# %%
sqlEngine = create_engine('mysql+pymysql://root:Mysqlworkbench21@127.0.0.1/amazon_ASIN', pool_recycle=3600)

dbConnection    = sqlEngine.connect()

# This is for creating data base
#sqlEngine.execute("CREATE DATABASE IF NOT EXISTS AMAZON") #create db
sqlEngine.execute("USE amazon_ASIN") # select new db

tableName   = "summary2"


try:
    frame = summary2.to_sql(tableName, dbConnection, if_exists='replace',index = False)

except ValueError as vx:
    print(vx)

except Exception as ex:   
    print(ex)

else:
    print("Table %s created successfully."%tableName);   

finally:
    dbConnection.close()
# Out:
# Table summary2 created successfully.
