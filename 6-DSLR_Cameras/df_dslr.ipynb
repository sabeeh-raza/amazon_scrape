# %%
import numpy as np
import pandas as pd

import warnings
warnings.filterwarnings("ignore")

# %%
# Create DataFrame from output_json file for laptop

df = pd.read_json('search_dslr_output.jsonl')
df
# Out:
#                                                   title  \
# 0     Pentax K-3 Mark III Flagship APS-C Black Camer...
# 1     FEELWORLD LUT6 6 Inch 2600nits HDR 3D LUT Touc...
# 2     Canon EOS Rebel T7 DSLR Camera with 18-55mm Le...
# 3     Canon EOS 4000D / Rebel T100 DSLR Camera with ...
# 4     Canon EOS 2000D (Rebel T7) DSLR Camera w/Canon...
# ...                                                 ...
# 2381  36 Pcs Camera Cleaning Kits,DanziX Professiona...
# 2382  Manfrotto MKCOMPACTADV-BK Compact Advanced Tri...
# 2383  Mini Tripod PICTRON MT-14 Mini Camera Tripod w...
# 2384  Osee T7 7 Inch Ultra Bright 3000 Nits Daylight...
# 2385  JULUCKY Black Ebony Handle Top NATO Handle Gri...
#
#                                                     url              rating  \
# 0     https://www.amazon.com/gp/slredirect/picassoRe...  4.9 out of 5 stars
# 1     https://www.amazon.com/gp/slredirect/picassoRe...  4.3 out of 5 stars
# 2     https://www.amazon.com/Canon-Rebel-T7-18-55mm-...  4.8 out of 5 stars
# 3     https://www.amazon.com/18-55mm-SanDisk-Backpac...  4.5 out of 5 stars
# 4     https://www.amazon.com/Canon-EOS-Camera-18-55m...  4.7 out of 5 stars
# ...                                                 ...                 ...
# 2381  https://www.amazon.com/Cleaning-DanziX-Profess...  4.6 out of 5 stars
# 2382  https://www.amazon.com/Manfrotto-MKCOMPACTADV-...  4.7 out of 5 stars
# 2383  https://www.amazon.com/Extendable-Tabletop-And...  4.6 out of 5 stars
# 2384  https://www.amazon.com/gp/slredirect/picassoRe...  4.3 out of 5 stars
# 2385  https://www.amazon.com/gp/slredirect/picassoRe...  5.0 out of 5 stars
#
#      review_count      price
# 0              18  $1,996.95
# 1              72    $289.99
# 2           1,197       None
# 3              67    $464.99
# 4             432    $509.00
# ...           ...        ...
# 2381           87     $10.99
# 2382           30       None
# 2383          127     $24.95
# 2384           31    $341.76
# 2385            2     $26.99
#
# [2386 rows x 5 columns]

# %% [markdown]
# ## Performing following operations on the DataFrame
# - Checking data type for the columns
# - Price column: remove '$' and ',', also change the type to float
# - Review_count cloumn: remove ',', also change the type to float
# - Rating column: Extract ONLY product rating form the column
#
# - Check null values for the columns. Remove rows without price, rating and review_count
# - Remove duplicate rows
#
# - Add Product column and write 'processor' in it

# %%
# Checking the data type

df.dtypes
# Out:
# title           object
# url             object
# rating          object
# review_count    object
# price           object
# dtype: object

# %%
df.isnull().sum()
# Out:
# title             0
# url               0
# rating          112
# review_count    112
# price           512
# dtype: int64

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# title           0
# url             0
# rating          0
# review_count    0
# price           0
# dtype: int64

# %%
df.shape
# Out:
# (1788, 5)

# %%
# Price column: remove '$' and ',', also change the type to float

df['price'] = df['price'].str.replace(',', '')
df['price'] = df['price'].str.replace('$', '')
df['price'] = df['price'].astype(float)

# %%
# Review_count cloumn: remove ',', also change the type to float

df['review_count'] = df['review_count'].str.replace(',', '')
df['review_count'] = df['review_count'].astype(float)
df['review_count'] = df['review_count'].astype(int)

# %%
# Rating column: Extract ONLY product rating form the column

df.rating = df.rating.astype('category')
df['rating'] = df['rating'].str.extract("(\d*\.?\d+)", expand=True)

# %%
df.dtypes
# Out:
# title            object
# url              object
# rating           object
# review_count      int64
# price           float64
# dtype: object

# %%
df
# Out:
#                                                   title  \
# 0     Pentax K-3 Mark III Flagship APS-C Black Camer...
# 1     FEELWORLD LUT6 6 Inch 2600nits HDR 3D LUT Touc...
# 3     Canon EOS 4000D / Rebel T100 DSLR Camera with ...
# 4     Canon EOS 2000D (Rebel T7) DSLR Camera w/Canon...
# 5     Canon EOS 4000D DSLR Camera with 18-55mm f/3.5...
# ...                                                 ...
# 2379  55mm Star Filter 3 Pieces Starburst Lens Filte...
# 2381  36 Pcs Camera Cleaning Kits,DanziX Professiona...
# 2383  Mini Tripod PICTRON MT-14 Mini Camera Tripod w...
# 2384  Osee T7 7 Inch Ultra Bright 3000 Nits Daylight...
# 2385  JULUCKY Black Ebony Handle Top NATO Handle Gri...
#
#                                                     url rating  review_count  \
# 0     https://www.amazon.com/gp/slredirect/picassoRe...    4.9            18
# 1     https://www.amazon.com/gp/slredirect/picassoRe...    4.3            72
# 3     https://www.amazon.com/18-55mm-SanDisk-Backpac...    4.5            67
# 4     https://www.amazon.com/Canon-EOS-Camera-18-55m...    4.7           432
# 5     https://www.amazon.com/Camera-18-55mm-3-5-5-6-...    4.6            20
# ...                                                 ...    ...           ...
# 2379  https://www.amazon.com/Filter-Pieces-Starburst...    4.5           695
# 2381  https://www.amazon.com/Cleaning-DanziX-Profess...    4.6            87
# 2383  https://www.amazon.com/Extendable-Tabletop-And...    4.6           127
# 2384  https://www.amazon.com/gp/slredirect/picassoRe...    4.3            31
# 2385  https://www.amazon.com/gp/slredirect/picassoRe...    5.0             2
#
#         price
# 0     1996.95
# 1      289.99
# 3      464.99
# 4      509.00
# 5      439.00
# ...       ...
# 2379    16.85
# 2381    10.99
# 2383    24.95
# 2384   341.76
# 2385    26.99
#
# [1788 rows x 5 columns]

# %%
df.groupby(['title'])['rating'].count().sort_values(ascending = False)
# Out:
# title
# Osee T5 5.5 Inch DSLR Mirrorless Camera Field 3D Lut Monitor Kit 1920×1080 IPS Full HD 4K HDMI Including HDMI Cables Tilt Arm and Sunshade                                                                 102
# Osee G7 7 Inch Ultra-Bright 3000 Nits DSLR Camera Field HDR Monitor 1920×1200 Full HD 3G SDI 4K HDMI in&Out Including Arm Trestle Dtap Cable Power Adaptor V Mount Battery Plate Sunshade and Hard Case    100
# 4k Camcorder with Microphone 56MP WiFi Camera with 16X Digital Zoom and Night Vision Live Streaming Recorder for YouTube Vlogging Camera Photography Stabilizer Remote Control (2 Batteries Included)       74
# SEETEC P133-9HSD 13.3 Inch Pro SDI Broadcast Monitor Professional LCD Director Studio Production Monitoring IPS Screen Full HD 1920×1080 Aluminum Design with 3G-SDI 4K HDMI AV YPbPr                       70
# Osee T7 7 Inch Ultra Bright 3000 Nits Daylight Viewable DSLR Camera Field 3D Lut HDR Monitor 1920×1200 Full HD IPS Support 4K HDMI Input & Output Including Ball Head AC Power Adaptor and D-tap Cable      60
#                                                                                                                                                                                                           ...
# Extreme Performance High Speed UHS-I SDXC 128GB SD Card 90/60 MB/S U3 A1 Class-10 V30 Memory Card Designed for SD Devices That can Capture Full HD, 3D, and 4K Video as Well as raw Photography              1
# FALCAM F38 Camera Quick Release Plate w 1/4" to 3/8" Screw Thread, Quick Release System QR Plate Camera Tripod Mount Adapter for Sony Canon Monopod DSLR Stabilizer Slider DJI Switch Between Stablizer      1
# FEELWORLD F5 5 Inch DSLR On Camera Field Monitor Small Full HD 1920x1080 IPS Video Peaking Focus Assist with 4K HDMI 8.4V DC Input Output Include Tilt Arm                                                   1
# FEELWORLD F5 Pro 5.5 Inch Touch Screen DSLR Camera Field Monitor with External Kit Install The Equipment IPS FHD1920x1080 4K HDMI Input Output 5 V Type-c Input Lightweight DesignTilt Arm Sun Shade         1
# 【Tilt Tension Design】 RAUBAY 70.8" Professional Heavy Duty Video Camera Tripod with Fluid Head and 2 QR Plates for DSLR Camcorder, Max Loading 17.6lbs, Aluminum Twin Tube Leg with Mid-Level Spreader       1
# Name: rating, Length: 1071, dtype: int64

# %%
df = df.drop_duplicates(subset=['title'])
df
# Out:
#                                                   title  \
# 0     Pentax K-3 Mark III Flagship APS-C Black Camer...
# 1     FEELWORLD LUT6 6 Inch 2600nits HDR 3D LUT Touc...
# 3     Canon EOS 4000D / Rebel T100 DSLR Camera with ...
# 4     Canon EOS 2000D (Rebel T7) DSLR Camera w/Canon...
# 5     Canon EOS 4000D DSLR Camera with 18-55mm f/3.5...
# ...                                                 ...
# 2377  Hahnel PROCUBE2 Professional Twin Battery Char...
# 2378  CADeN Camera Bag Case Shoulder Messenger Cross...
# 2379  55mm Star Filter 3 Pieces Starburst Lens Filte...
# 2381  36 Pcs Camera Cleaning Kits,DanziX Professiona...
# 2383  Mini Tripod PICTRON MT-14 Mini Camera Tripod w...
#
#                                                     url rating  review_count  \
# 0     https://www.amazon.com/gp/slredirect/picassoRe...    4.9            18
# 1     https://www.amazon.com/gp/slredirect/picassoRe...    4.3            72
# 3     https://www.amazon.com/18-55mm-SanDisk-Backpac...    4.5            67
# 4     https://www.amazon.com/Canon-EOS-Camera-18-55m...    4.7           432
# 5     https://www.amazon.com/Camera-18-55mm-3-5-5-6-...    4.6            20
# ...                                                 ...    ...           ...
# 2377  https://www.amazon.com/Hahnel-PROCUBE2-Profess...    4.6            38
# 2378  https://www.amazon.com/CADeN-Messenger-Compati...    4.2            26
# 2379  https://www.amazon.com/Filter-Pieces-Starburst...    4.5           695
# 2381  https://www.amazon.com/Cleaning-DanziX-Profess...    4.6            87
# 2383  https://www.amazon.com/Extendable-Tabletop-And...    4.6           127
#
#         price
# 0     1996.95
# 1      289.99
# 3      464.99
# 4      509.00
# 5      439.00
# ...       ...
# 2377    79.90
# 2378    19.99
# 2379    16.85
# 2381    10.99
# 2383    24.95
#
# [1071 rows x 5 columns]

# %%
# Inserting 'product name' column at the start

df.insert(0, 'Product', 'DSLR')

# %%
df
# Out:
#      Product                                              title  \
# 0       DSLR  Pentax K-3 Mark III Flagship APS-C Black Camer...
# 1       DSLR  FEELWORLD LUT6 6 Inch 2600nits HDR 3D LUT Touc...
# 3       DSLR  Canon EOS 4000D / Rebel T100 DSLR Camera with ...
# 4       DSLR  Canon EOS 2000D (Rebel T7) DSLR Camera w/Canon...
# 5       DSLR  Canon EOS 4000D DSLR Camera with 18-55mm f/3.5...
# ...      ...                                                ...
# 2377    DSLR  Hahnel PROCUBE2 Professional Twin Battery Char...
# 2378    DSLR  CADeN Camera Bag Case Shoulder Messenger Cross...
# 2379    DSLR  55mm Star Filter 3 Pieces Starburst Lens Filte...
# 2381    DSLR  36 Pcs Camera Cleaning Kits,DanziX Professiona...
# 2383    DSLR  Mini Tripod PICTRON MT-14 Mini Camera Tripod w...
#
#                                                     url rating  review_count  \
# 0     https://www.amazon.com/gp/slredirect/picassoRe...    4.9            18
# 1     https://www.amazon.com/gp/slredirect/picassoRe...    4.3            72
# 3     https://www.amazon.com/18-55mm-SanDisk-Backpac...    4.5            67
# 4     https://www.amazon.com/Canon-EOS-Camera-18-55m...    4.7           432
# 5     https://www.amazon.com/Camera-18-55mm-3-5-5-6-...    4.6            20
# ...                                                 ...    ...           ...
# 2377  https://www.amazon.com/Hahnel-PROCUBE2-Profess...    4.6            38
# 2378  https://www.amazon.com/CADeN-Messenger-Compati...    4.2            26
# 2379  https://www.amazon.com/Filter-Pieces-Starburst...    4.5           695
# 2381  https://www.amazon.com/Cleaning-DanziX-Profess...    4.6            87
# 2383  https://www.amazon.com/Extendable-Tabletop-And...    4.6           127
#
#         price
# 0     1996.95
# 1      289.99
# 3      464.99
# 4      509.00
# 5      439.00
# ...       ...
# 2377    79.90
# 2378    19.99
# 2379    16.85
# 2381    10.99
# 2383    24.95
#
# [1071 rows x 6 columns]

# %%
df.to_csv('dslr_output.csv', index=False)
